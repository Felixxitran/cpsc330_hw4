# %%
# Initialize Otter
import otter
grader = otter.Notebook("hw4.ipynb")

# %% [markdown]
# # CPSC 330 - Applied Machine Learning
#
# ## Homework 4: Logistic regression, hyperparameter optimization
# ### Associated lectures: [Lectures 7, 8](https://github.com/UBC-CS/cpsc330-2024W1/tree/main/lectures)
#
# **Due date: [Feb 10, 11:59 pm](https://github.com/UBC-CS/cpsc330-2024W2?tab=readme-ov-file#deliverable-due-dates-tentative).**

# %% [markdown]
# ## Imports

# %%
from hashlib import sha1

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

plt.rcParams["font.size"] = 16

from sklearn.dummy import DummyClassifier
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import (
    GridSearchCV,
    cross_val_score,
    cross_validate,
    train_test_split,
)
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.tree import DecisionTreeClassifier

# %%
import hashlib


def my_sha1(text):
    return hashlib.sha1(text.encode("utf-8")).hexdigest()

# %% [markdown]
# <br><br>

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# <div class="alert alert-info">
#
# ## Submission instructions
# <hr>
# rubric={points}
#
# **You may work with a partner on this homework and submit your assignment as a group.** Below are some instructions on working as a group.
# - The maximum group size is 2.
# - Use group work as an opportunity to collaborate and learn new things from each other.
# - Be respectful to each other and make sure you understand all the concepts in the assignment well.
# - It's your responsibility to make sure that the assignment is submitted by one of the group members before the deadline.
# - You can find the instructions on how to do group submission on Gradescope [here](https://help.gradescope.com/article/m5qz2xsnjy-student-add-group-members).
# - If you would like to use late tokens for the homework, all group members must have the necessary late tokens available. Please note that the late tokens will be counted for all members of the group.
#
#
# Follow the [homework submission instructions](https://github.com/UBC-CS/cpsc330-2024W2/blob/master/docs/homework_instructions.md).
#
# 1. Before submitting the assignment, run all cells in your notebook to make sure there are no errors by doing `Kernel -> Restart Kernel and Clear All Outputs` and then `Run -> Run All Cells`.
# 2. Notebooks with cell execution numbers out of order will have marks deducted. Notebooks without the output displayed may not be graded at all (because we need to see the output in order to grade your work).
# 3. Follow the [CPSC 330 homework instructions](https://ubc-cs.github.io/cpsc330-2024W2/docs/homework_instructions.html), which include information on how to do your assignment and how to submit your assignment.
# 4. Upload your solution on Gradescope. Check out this [Gradescope Student Guide](https://lthub.ubc.ca/guides/gradescope-student-guide/) if you need help with Gradescope submission.
# 5. Make sure that the plots and output are rendered properly in your submitted file. If the .ipynb file is too big and doesn't render on Gradescope, also upload a pdf or html in addition to the .ipynb so that the TAs can view your submission on Gradescope.
#
#
# _Note: The assignments will get gradually more open-ended as we progress through the course. In many cases, there won't be a single correct solution. Sometimes you will have to make your own choices and your own decisions (for example, on what parameter values to use when they are not explicitly provided in the instructions). Use your own judgment in such cases and justify your choices, if necessary._
#
# </div>
#
# _Points:_ 4

# %% [markdown]
# <!-- END QUESTION -->
#
# <br><br><br><br>

# %% [markdown]
# ## Exercise 1: implementing `DummyClassifier`
# <hr>
# rubric={autograde}
#
# In this course (unlike CPSC 340) you will generally **not** be asked to implement machine learning algorihtms (like logistic regression) from scratch. However, this exercise is an exception: you will implement the simplest possible classifier, `DummyClassifier`.
#
# As a reminder, `DummyClassifier` is meant as a baseline and is generally a simple "model" you could "fit" to a dataset. All it does is predict the most popular class in the training set. So if there are more 0s than 1s it predicts 0 every time, and if there are more 1s than 0s it predicts 1 every time. For `predict_proba` it looks at the frequencies in the training set, so if you have 30% 0's and 70% 1's it predicts `[0.3 0.7]` every time. Thus, `fit` only looks at `y` (not `X`).
#
# Below you will find starter code for a class called `MyDummyClassifier`, which has methods `fit()`, `predict()`, `predict_proba()` and `score()`. Your task is to fill in those four functions. To get you started, I have given you a `return` statement in each case that returns the correct data type:
# - `fit` returns nothing
# - `predict` returns an array whose size is the number of examples
# - `predict_proba` returns an array whose size is the number of examples x 2, and
# - `score` returns a float
#
# The next code block has some tests you can use to assess whether your code is working.
#
# I suggest starting with `fit` and `predict`, and making sure those are working before moving on to `predict_proba`. For `predict_proba`, you should return the frequency of each class in the training data. **Your `score` function should call your `predict` function**. Again, you can compare with `DummyClassifier` using the code below.
#
# `sklearn`'s `DummyClassifier` works when you have more than two classes, and also works if the target values are encoded differently, for example as "cat", "dog", "eagle", etc. However, for the sake of simplifying this question, we will consider **binary classification** only. Furthermore, we will assume that these classes are encoded as 0 and 1. In other words, you can safely assume that the variable y contains only 0's and 1's

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_1
#
# </div>

# %%
class MyDummyClassifier:
    """
    A baseline classifier that predicts the most common class.
    The predicted probabilities come from the relative frequencies
    of the classes in the training data.

    This implementation only works when y only contains 0s and 1s.
    """
    zeros = 0 
    ones = 0 

    def fit(self, X, y):
        num_ones = np.sum(y)
        num_zeros = len(y) - num_ones 
        self.zeros = num_zeros/len(y)
        self.ones = num_ones/len(y)
        ...
        return None  # Replace with your code

    def predict(self, X):
        if self.ones>=0.5:
            return np.ones(X.shape[0])
        else:
            return np.zeros(X.shape[0])
        ...
          # Replace with your code

    def predict_proba(self, X):
        prob = np.zeros((X.shape[0], 2))
        prob[:, 1] = self.ones
        prob[:, 0] = self.zeros
        ...
        return prob  # Replace with your code

    def score(self, X, y):
        prediction = self.predict(X)
        accuracy = np.count_nonzero(prediction == y)/len(y)
        ...
        return accuracy  # Replace with your code

# %% [markdown]
# Below are some tests for `predict` using randomly generated data. You may want to run the cell a few times to make sure you explore the different cases (or automate this with a loop or random seeds).

# %%
# For testing, generate random data
n_train = 101
n_valid = 21
d = 5
X_train_dummy = np.random.randn(n_train, d)
X_valid_dummy = np.random.randn(n_valid, d)
y_train_dummy = np.random.randint(2, size=n_train)
y_valid_dummy = np.random.randint(2, size=n_valid)

my_dc = MyDummyClassifier()
sk_dc = DummyClassifier(strategy="prior")

my_dc.fit(X_train_dummy, y_train_dummy)
sk_dc.fit(X_train_dummy, y_train_dummy)

assert np.array_equal(my_dc.predict(X_train_dummy), sk_dc.predict(X_train_dummy))
assert np.array_equal(my_dc.predict(X_valid_dummy), sk_dc.predict(X_valid_dummy))

# %% [markdown]
# Below are some tests for `predict_proba`.

# %%
assert np.allclose(
    my_dc.predict_proba(X_train_dummy), sk_dc.predict_proba(X_train_dummy)
)
assert np.allclose(
    my_dc.predict_proba(X_valid_dummy), sk_dc.predict_proba(X_valid_dummy)
)

# %% [markdown]
# Below are some tests for `score`.
#
# _Points:_ 10

# %%
assert np.isclose(
    my_dc.score(X_train_dummy, y_train_dummy), sk_dc.score(X_train_dummy, y_train_dummy)
)
assert np.isclose(
    my_dc.score(X_valid_dummy, y_valid_dummy), sk_dc.score(X_valid_dummy, y_valid_dummy)
)

# %%
grader.check("q1")
# Out:
# q1 results: All test cases passed!

# %% [markdown]
# ## Exercise 2: Trump Tweets
# <hr>
#
# For the rest of this assignment we'll be working with a [dataset of Donald Trump's tweets](https://www.kaggle.com/austinreese/trump-tweets) as of June 2020. You should start by downloading the dataset. Unzip it and move the file `realdonaldtrump.csv` under the data directory in this folder. As usual, please do not submit the dataset when you submit the assignment.

# %%
tweets_df = pd.read_csv("data/realdonaldtrump.csv", index_col=0)
tweets_df.head()
# Out:
#                                                          link  \
# id
# 1698308935  https://twitter.com/realDonaldTrump/status/169...
# 1701461182  https://twitter.com/realDonaldTrump/status/170...
# 1737479987  https://twitter.com/realDonaldTrump/status/173...
# 1741160716  https://twitter.com/realDonaldTrump/status/174...
# 1773561338  https://twitter.com/realDonaldTrump/status/177...
#
#                                                       content  \
# id
# 1698308935  Be sure to tune in and watch Donald Trump on L...
# 1701461182  Donald Trump will be appearing on The View tom...
# 1737479987  Donald Trump reads Top Ten Financial Tips on L...
# 1741160716  New Blog Post: Celebrity Apprentice Finale and...
# 1773561338  "My persona will never be that of a wallflower...
#
#                            date  retweets  favorites mentions hashtags
# id
# 1698308935  2009-05-04 13:54:25       510        917      NaN      NaN
# 1701461182  2009-05-04 20:00:10        34        267      NaN      NaN
# 1737479987  2009-05-08 08:38:08        13         19      NaN      NaN
# 1741160716  2009-05-08 15:40:15        11         26      NaN      NaN
# 1773561338  2009-05-12 09:07:28      1375       1945      NaN      NaN

# %%
tweets_df.shape
# Out:
# (43352, 7)

# %% [markdown]
# We will be trying to predict whether a tweet will go "viral", defined as having more than 10,000 retweets:

# %%
y = tweets_df["retweets"] > 10_000

# %% [markdown]
# To make predictions, we'll be using only the content (text) of the tweet.

# %%
X = tweets_df["content"]

# %% [markdown]
# For the purpose of this assignment, you can ignore all the other columns in the original dataset.

# %% [markdown]
# <br><br>

# %% [markdown]
# <br><br>

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ### 2.1 Ordering the steps
# rubric={points}
#
# Let's start by building a model using `CountVectorizer` and `LogisticRegression`. The code required to do this has been provided below, but in the wrong order.
#
# **Your tasks:**
# 1. Rearrange the lines of code to correctly fit the model and compute the cross-validation score.
# 2. Add a short comment above each step to describe what the code is doing.

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_2.1
#
# </div>
#
# _Points:_ 5

# %%
...# YOUR COMMENT HERE
#create a CountVectorizer in with bag of words in English
countvec = CountVectorizer(stop_words="english")

# YOUR COMMENT HERE
#split the original set of data into training and test set with the ratio 0.6 for test data and 0.4 for training data 
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.6, random_state=123
)


# YOUR COMMENT HERE
#create logisticRegression model with 
lr = LogisticRegression(max_iter=1000, random_state=123)

# YOUR COMMENT HERE
#make pipeline with Count Vectorize and logisticRegression model
pipe = make_pipeline(countvec, lr)


# YOUR COMMENT HERE
#preform cross validation on Logistic regresssion with training dataset
cv_score = cross_val_score(pipe, X_train, y_train).mean()
print(cv_score)
# Out:
# 0.8953863898500576

# %% [markdown]
# <!-- END QUESTION -->
#
# <br><br>

# %% [markdown]
# ### 2.2 Baseline
# rubric={autograde}
#
# **Your tasks:**
#
# 1. Run 5-fold cross-validation with `sklearn`'s `DummyClassifier` on this dataset. Store the mean cross-validation score in a variable called `dummy_cv_score` given below.
#
# > You should be able to use `MyDummyClassifier` above. But sklearn will likely complain if you try to pass it to `cross_val_score` or `cross_validate`.

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_2.2
#
# </div>
#
# _Points:_ 2

# %%
dummyModel = DummyClassifier()
dummy_cv_score = cross_val_score(dummyModel,X_train,y_train,cv=5).mean()
print(dummy_cv_score)
...
# Out:
# 0.7423875432525952
# Ellipsis

# %%
grader.check("q2.2")
# Out:
# q2.2 results: All test cases passed!

# %% [markdown]
# <br><br>

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ### 2.3 Discussion
# rubric={points}
#
# **Your tasks:**
#
# 1. Compare the `DummyClassifier` score to what you got from logistic regression above. Does logistic regression seem to be doing anything useful?
# 2. Above we averaged the scores from the 5 folds of cross-validation of logistic regression. Print out the 5 individual scores. Reminder: `sklearn` calls them `"test_score"` but they are really (cross-)validation scores.
# 3. Are the 5 scores close to each other or spread far apart? (This is a bit subjective, answer to the best of your ability.)
# 4. How does the size of this dataset (number of rows) compare to [the cities dataset](https://github.com/UBC-CS/cpsc330-2023W1/blob/main/lectures/data/canada_usa_cities.csv) we have been using in the lecture notes? How does this relate to the different sub-scores from the 5 folds?

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_2.3
#
# </div>
#
# _Points:_ 4

# %% [markdown]
# 1.The DummyClassifier mean score is 0.74 while the score for LogisticRegression is around 0.89. Clearly, LogisticRegression is better than DummyClassifier
# 2.

# %%
test_scores = cross_val_score(pipe, X_train, y_train)
print(test_scores)
# Out:
# [0.89186851 0.90023068 0.89561707 0.88956171 0.89965398]

# %% [markdown]
# 3. The 5 score are close to each other since all of them are around 0.89
# 4. The shape of this data is (43352,7) with 43352 samples while the cities dataset only have 209 samples.Clearly trumph data set is larger.As a result when doing cross-validation each fold still have a significant amount of dataset which causes the set of scores to be quite consistent and relatably similar to each other

# %% [markdown]
# <!-- END QUESTION -->
#
# <br><br>

# %% [markdown]
# ### 2.4 Probability scores
# rubric={autograde}
#
# Here we train a logistic regression classifier on the entire training set:

# %%
pipe_lr = make_pipeline(
    CountVectorizer(stop_words="english"),
    LogisticRegression(max_iter=1000, random_state=123),
)
pipe_lr.fit(X_train, y_train);

# %% [markdown]
# **Your tasks:**
#
# 1. Using this model, find the tweet in the **test set** with the highest predicted probability of being viral. Store the tweet and the associated probability in the variables `tweet` and `prob`, respectively.
#
# > Reminder: you are free to reuse/adapt code from lecture. Please add in a small attribution, e.g. "From Lecture 7".

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_2.4
#
# </div>
#
# _Points:_ 4

# %%
# From Lecture 7
probs = pipe_lr.predict_proba(X_test)[:, 1]
print(probs)
max_prob_index = np.argmax(probs)
tweet = X_test.iloc[max_prob_index]
print(tweet)
prob = probs[max_prob_index]
print(prob)
...
# Out:
# [0.56167711 0.98786534 0.59222924 ... 0.0019337  0.13821946 0.00212434]
# There was No Collusion with Russia (except by the Democrats). When will this very expensive Witch Hunt Hoax ever end? So bad for our Country. Is the Special Counsel/Justice Department leaking my lawyers letters to the Fake News Media? Should be looking at Dems corruption instead?
# 0.9999999830416225
# Ellipsis

# %%
grader.check("q2.4")
# Out:
# q2.4 results: All test cases passed!

# %% [markdown]
# <br><br>

# %% [markdown]
# ### 2.5 Coefficients
# rubric={autograde}
#
# We can extract the `CountVectorizer` and `LogisticRegression` objects from the `Pipeline` object as follows:

# %%
vec_from_pipe = pipe_lr.named_steps["countvectorizer"]
lr_from_pipe = pipe_lr.named_steps["logisticregression"]

# %% [markdown]
# **Your tasks:**
#
# Using these extracted components above, get the five words with the highest coefficients and 5 words with smallest coefficients. Store them as lists in `top_5_words` and `bottom_5_words` variables, respectively.

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_2.5
#
# </div>
#
# _Points:_ 4

# %%
feature_names = vec_from_pipe.get_feature_names_out()
coeffs = lr_from_pipe.coef_.flatten()
word_coeff_df = pd.DataFrame(coeffs, index=feature_names, columns=["Coefficient"])
word_sorted = word_coeff_df.sort_values(by="Coefficient", ascending=False)
print(word_sorted)
top_5_words = word_sorted.head(5).index.tolist()
bottom_5_words = word_sorted.tail(5).index.tolist() # Store them as a list

...
# Out:
#                  Coefficient
# democrats           2.522409
# transcripts         2.416380
# harassment          2.393406
# coronavirus         2.200156
# fake                2.070058
# ...                      ...
# thanks             -1.820247
# donaldtrump        -1.988505
# trump2016pic       -2.003314
# barackobama        -2.196487
# realdonaldtrump    -3.154153
#
# [27345 rows x 1 columns]
# Ellipsis

# %%
top_5_words
# Out:
# ['democrats', 'transcripts', 'harassment', 'coronavirus', 'fake']

# %%
bottom_5_words
# Out:
# ['thanks', 'donaldtrump', 'trump2016pic', 'barackobama', 'realdonaldtrump']

# %%
grader.check("q2.5")
# Out:
# q2.5 results: All test cases passed!

# %% [markdown]
# <br><br>

# %% [markdown]
# ### 2.6 Running a cross-validation fold without sklearn tools
# rubric={autograde}
#
# Sklearn provides a lot of useful tools like `make_pipeline` and `cross_validate`, which are awesome. But with these fancy tools it's also easy to lose track of what is actually happening under the hood.
#
# **Your tasks:**
#
# 1. Compute logistic regression's validation score on the first fold, that is, train on 80% and validate on 20% of the training data (`X_train`) without using sklearn `Pipeline` or `cross_validate` or `cross_val_score`. Store the score of the fold in a variable called `fold_score`. Recall that `cross_validation` in `sklearn` does not shuffle the data by default.
#
# You should start with the following `CountVectorizer` and `LogisticRegression` objects, as well as `X_train` and `y_train` (which you should further split with `train_test_split` and `shuffle=False`):
# > Note: avoid assigning the variable names `X_train`, `y_train`, `X_test`, `y_test` to your folds when you call `train_test_split`. You'll be using those again later in the assignment.

# %%
countvec = CountVectorizer(stop_words="english")
lr = LogisticRegression(max_iter=1000, random_state=123)

# %% [markdown]
# > Meta-comment: you might be wondering why we're going into "implementation" here if this course is about _applied_ ML. In CPSC 340, we would go all the way down into `LogisticRegression` and understand how `fit` works, line by line. Here we're not going into that at all, but I still think this type of question (and Exercise 1) is a useful middle ground. I do want you to know what is going on in `Pipeline` and in `cross_validate` even if we don't cover the details of `fit`. To get into logistic regression's `fit` requires a bunch of math; here, we're keeping it more conceptual and avoiding all those prerequisites.

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_2.6
#
# </div>
#
# _Points:_ 8

# %%
X_train_split, X_valid_split, y_train_split, y_valid_split = train_test_split(X_train, y_train, test_size = 0.2, random_state = 123, shuffle = False)
X_train_vec = countvec.fit_transform(X_train_split)
X_valid_vec = countvec.transform(X_valid_split)
lr.fit(X_train_vec, y_train_split)
fold_score = lr.score(X_valid_vec, y_valid_split)
print(fold_score)

...
# Out:
# 0.9008073817762399
# Ellipsis

# %%
fold_score
# Out:
# 0.9008073817762399

# %%
grader.check("q2.6")
# Out:
# q2.6 results: All test cases passed!

# %% [markdown]
# <br><br><br><br>

# %% [markdown]
# ## Exercise 3: Hyperparameter optimization
# <hr>

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ### 3.1 Optimizing `max_features` of `CountVectorizer`
# rubric={points}
#
# The following code varies the `max_features` hyperparameter of `CountVectorizer` and makes a plot (with the x-axis on a log scale) that shows train/cross-validation scores vs. `max_features`. It also prints the results.
#
# **Your tasks:**
# - Based on the plot/output, what value of `max_features` seems best? Briefly explain.
#
# > The code may take a minute or two to run. You can uncomment the `print` statement if you want to see it show the progress.

# %%
train_scores = []
cv_scores = []

max_features = [10, 100, 1000, 10_000, 100_000]

for mf in max_features:
    #     print(mf)
    pipe = make_pipeline(
        CountVectorizer(stop_words="english", max_features=mf),
        LogisticRegression(max_iter=1000, random_state=123),
    )
    cv_results = cross_validate(pipe, X_train, y_train, return_train_score=True)
    train_scores.append(cv_results["train_score"].mean())
    cv_scores.append(cv_results["test_score"].mean())

plt.semilogx(max_features, train_scores, label="train")
plt.semilogx(max_features, cv_scores, label="valid")
plt.legend()
plt.xlabel("max_features")
plt.ylabel("accuracy");

# %%
pd.DataFrame({"max_features": max_features, "train": train_scores, "cv": cv_scores})
# Out:
#    max_features     train        cv
# 0            10  0.772131  0.771511
# 1           100  0.843339  0.839158
# 2          1000  0.911851  0.884429
# 3         10000  0.964317  0.895329
# 4        100000  0.976399  0.895386

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_3.1
#
# </div>
#
# _Points:_ 2

# %% [markdown]
# _Type your answer here, replacing this text._

# %% [markdown]
# For max_features <10000 , the training score and validation score are too close to each other, which may shows possibility of underfitting. When the max_features is 100000, the training score is too high almost perfect which may shows sign for overfitting. When the max_features = 10000, it has reasonable training score and relatively high cv score, therefore, max_features = 10000 seems to be the best max_features.

# %% [markdown]
# <!-- END QUESTION -->
#
# <br><br>

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ### 3.2 Optimizing `C` of `LogisticRegression`
# rubric={points}
#
# The following code varies the `C` hyperparameter of `LogisticRegression` and makes a plot (with the x-axis on a log scale) that shows train/cross-validation scores vs. `C`.
#
# **Your tasks:**
#
# - Based on the plot, what value of `C` seems best? Briefly explain.
#
# > The code may take a minute or two to run. You can uncomment the `print` statement if you want to see it show the progress.

# %%
train_scores = []
cv_scores = []

C_vals = 10.0 ** np.arange(-1.5, 2, 0.5)

for C in C_vals:
    #     print(C)
    pipe = make_pipeline(
        CountVectorizer(stop_words="english"),
        LogisticRegression(max_iter=1000, C=C, random_state=123),
    )
    cv_results = cross_validate(pipe, X_train, y_train, return_train_score=True)

    train_scores.append(cv_results["train_score"].mean())
    cv_scores.append(cv_results["test_score"].mean())

plt.semilogx(C_vals, train_scores, label="train")
plt.semilogx(C_vals, cv_scores, label="valid")
plt.legend()
plt.xlabel("C")
plt.ylabel("accuracy");

# %%
pd.DataFrame({"C": C_vals, "train": train_scores, "cv": cv_scores})
# Out:
#            C     train        cv
# 0   0.031623  0.886318  0.869031
# 1   0.100000  0.921396  0.885813
# 2   0.316228  0.949596  0.894925
# 3   1.000000  0.976399  0.895386
# 4   3.162278  0.991133  0.892791
# 5  10.000000  0.996583  0.887486
# 6  31.622777  0.998025  0.883795

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_3.2
#
# </div>
#
# _Points:_ 2

# %% [markdown]
# Based on the graph and the outputs, we can see that the peak of cross validation score is at when C = 1, and it has relatively smaller training score compare to C > 1, which shows that is is unlikely to be overfitting. When C < 1, training score and cross validation score are quite close to each other and may shows signs of underfitting. Therefore, the best C would be 1.

# %% [markdown]
# <!-- END QUESTION -->
#
# <br><br>

# %% [markdown]
# ### 3.3 Hyperparameter optimization
# rubric={autograde}
#
# Start with the pipeline `pipe` below.
#
# **Your tasks:**
# - Create a `GridSearchCV` object named `grid_search` to jointly optimize `max_features` of `CountVectorizer` and `C` of `LogisticRegression` across all the combinations of values we tried above.
# - What are the best values of `max_features` and `C` according to your grid search? Store them in variables `best_max_features` and `best_C`, respectively.
# - Store the best score returned by the grid search in a variable called `best_score`.
#
# > The code might be a bit slow here. Setting `n_jobs=-1` should speed it up if you have a multi-core processor.

# %%
pipe_lr = make_pipeline(
    CountVectorizer(stop_words="english"),
    LogisticRegression(max_iter=1000, random_state=123),
)

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_3.3
#
# </div>
#
# _Points:_ 8

# %%
#code from lecture 8
param_grid = {
    'countvectorizer__max_features' : max_features,
    'logisticregression__C' : C_vals,
}
grid_search = GridSearchCV(
    pipe, param_grid, cv = 5, n_jobs = -1, return_train_score = True
) 
grid_search.fit(X_train,y_train)




...
# Out:
# Ellipsis

# %%
results = (
    pd.DataFrame(grid_search.cv_results_).set_index("rank_test_score").sort_index()
)
display(results.T)
# Out:
# rank_test_score                                                                     1   \
# mean_fit_time                                                                 0.993151
# std_fit_time                                                                  0.219946
# mean_score_time                                                               0.109358
# std_score_time                                                                0.056231
# param_countvectorizer__max_features                                             100000
# param_logisticregression__C                                                        1.0
# params                               {'countvectorizer__max_features': 100000, 'log...
# split0_test_score                                                             0.891869
# split1_test_score                                                             0.900231
# split2_test_score                                                             0.895617
# split3_test_score                                                             0.889562
# split4_test_score                                                             0.899654
# mean_test_score                                                               0.895386
# std_test_score                                                                0.004196
# split0_train_score                                                            0.977725
# split1_train_score                                                            0.976499
# split2_train_score                                                            0.976644
# split3_train_score                                                            0.977725
# split4_train_score                                                              0.9734
# mean_train_score                                                              0.976399
# std_train_score                                                               0.001586
#
# rank_test_score                                                                     2   \
# mean_fit_time                                                                 0.723908
# std_fit_time                                                                  0.282286
# mean_score_time                                                               0.110474
# std_score_time                                                                0.052858
# param_countvectorizer__max_features                                              10000
# param_logisticregression__C                                                        1.0
# params                               {'countvectorizer__max_features': 10000, 'logi...
# split0_test_score                                                             0.893022
# split1_test_score                                                             0.899366
# split2_test_score                                                             0.895329
# split3_test_score                                                             0.889273
# split4_test_score                                                             0.899654
# mean_test_score                                                               0.895329
# std_test_score                                                                0.003924
# split0_train_score                                                             0.96511
# split1_train_score                                                            0.963884
# split2_train_score                                                            0.964245
# split3_train_score                                                            0.965975
# split4_train_score                                                             0.96237
# mean_train_score                                                              0.964317
# std_train_score                                                               0.001213
#
# rank_test_score                                                                     3   \
# mean_fit_time                                                                 0.676758
# std_fit_time                                                                  0.095568
# mean_score_time                                                               0.138409
# std_score_time                                                                 0.10105
# param_countvectorizer__max_features                                             100000
# param_logisticregression__C                                                   0.316228
# params                               {'countvectorizer__max_features': 100000, 'log...
# split0_test_score                                                             0.891869
# split1_test_score                                                             0.901961
# split2_test_score                                                             0.893599
# split3_test_score                                                             0.890715
# split4_test_score                                                             0.896482
# mean_test_score                                                               0.894925
# std_test_score                                                                0.004019
# split0_train_score                                                            0.950332
# split1_train_score                                                            0.949611
# split2_train_score                                                            0.948025
# split3_train_score                                                            0.952062
# split4_train_score                                                            0.947953
# mean_train_score                                                              0.949596
# std_train_score                                                               0.001536
#
# rank_test_score                                                                     3   \
# mean_fit_time                                                                 0.598013
# std_fit_time                                                                  0.154381
# mean_score_time                                                               0.171079
# std_score_time                                                                 0.07668
# param_countvectorizer__max_features                                              10000
# param_logisticregression__C                                                   0.316228
# params                               {'countvectorizer__max_features': 10000, 'logi...
# split0_test_score                                                             0.891292
# split1_test_score                                                             0.902249
# split2_test_score                                                             0.894175
# split3_test_score                                                             0.890138
# split4_test_score                                                              0.89677
# mean_test_score                                                               0.894925
# std_test_score                                                                0.004329
# split0_train_score                                                            0.942402
# split1_train_score                                                            0.940888
# split2_train_score                                                             0.94096
# split3_train_score                                                              0.9437
# split4_train_score                                                            0.941176
# mean_train_score                                                              0.941825
# std_train_score                                                               0.001086
#
# rank_test_score                                                                     5   \
# mean_fit_time                                                                 0.911416
# std_fit_time                                                                  0.185123
# mean_score_time                                                               0.103996
# std_score_time                                                                0.039154
# param_countvectorizer__max_features                                             100000
# param_logisticregression__C                                                   3.162278
# params                               {'countvectorizer__max_features': 100000, 'log...
# split0_test_score                                                             0.887255
# split1_test_score                                                             0.895905
# split2_test_score                                                             0.893599
# split3_test_score                                                             0.886967
# split4_test_score                                                             0.900231
# mean_test_score                                                               0.892791
# std_test_score                                                                0.005104
# split0_train_score                                                            0.991061
# split1_train_score                                                            0.990845
# split2_train_score                                                             0.99171
# split3_train_score                                                            0.991133
# split4_train_score                                                            0.990917
# mean_train_score                                                              0.991133
# std_train_score                                                               0.000306
#
# rank_test_score                                                                     6   \
# mean_fit_time                                                                 0.795843
# std_fit_time                                                                  0.184718
# mean_score_time                                                               0.068651
# std_score_time                                                                0.035454
# param_countvectorizer__max_features                                              10000
# param_logisticregression__C                                                   3.162278
# params                               {'countvectorizer__max_features': 10000, 'logi...
# split0_test_score                                                             0.885525
# split1_test_score                                                             0.893599
# split2_test_score                                                             0.889562
# split3_test_score                                                             0.884948
# split4_test_score                                                             0.899654
# mean_test_score                                                               0.890657
# std_test_score                                                                0.005472
# split0_train_score                                                            0.980608
# split1_train_score                                                            0.979599
# split2_train_score                                                            0.980753
# split3_train_score                                                            0.981473
# split4_train_score                                                            0.979239
# mean_train_score                                                              0.980334
# std_train_score                                                               0.000811
#
# rank_test_score                                                                     7   \
# mean_fit_time                                                                 1.021527
# std_fit_time                                                                  0.128194
# mean_score_time                                                               0.088945
# std_score_time                                                                0.019144
# param_countvectorizer__max_features                                             100000
# param_logisticregression__C                                                       10.0
# params                               {'countvectorizer__max_features': 100000, 'log...
# split0_test_score                                                             0.882641
# split1_test_score                                                              0.89158
# split2_test_score                                                             0.887832
# split3_test_score                                                             0.876298
# split4_test_score                                                             0.899077
# mean_test_score                                                               0.887486
# std_test_score                                                                0.007745
# split0_train_score                                                             0.99654
# split1_train_score                                                            0.996324
# split2_train_score                                                            0.996612
# split3_train_score                                                             0.99654
# split4_train_score                                                              0.9969
# mean_train_score                                                              0.996583
# std_train_score                                                               0.000186
#
# rank_test_score                                                                     8   \
# mean_fit_time                                                                 0.643441
# std_fit_time                                                                  0.243166
# mean_score_time                                                               0.100201
# std_score_time                                                                0.043334
# param_countvectorizer__max_features                                             100000
# param_logisticregression__C                                                        0.1
# params                               {'countvectorizer__max_features': 100000, 'log...
# split0_test_score                                                             0.887255
# split1_test_score                                                              0.88812
# split2_test_score                                                              0.88639
# split3_test_score                                                             0.875721
# split4_test_score                                                              0.89158
# mean_test_score                                                               0.885813
# std_test_score                                                                0.005345
# split0_train_score                                                            0.923659
# split1_train_score                                                            0.913351
# split2_train_score                                                             0.92301
# split3_train_score                                                            0.924813
# split4_train_score                                                            0.922145
# mean_train_score                                                              0.921396
# std_train_score                                                               0.004116
#
# rank_test_score                                                                     9   \
# mean_fit_time                                                                 0.525163
# std_fit_time                                                                  0.125003
# mean_score_time                                                               0.110631
# std_score_time                                                                0.076238
# param_countvectorizer__max_features                                              10000
# param_logisticregression__C                                                        0.1
# params                               {'countvectorizer__max_features': 10000, 'logi...
# split0_test_score                                                             0.887255
# split1_test_score                                                             0.888408
# split2_test_score                                                             0.887255
# split3_test_score                                                             0.874567
# split4_test_score                                                             0.891292
# mean_test_score                                                               0.885755
# std_test_score                                                                0.005785
# split0_train_score                                                            0.917748
# split1_train_score                                                            0.909602
# split2_train_score                                                            0.917604
# split3_train_score                                                            0.914288
# split4_train_score                                                            0.917388
# mean_train_score                                                              0.915326
# std_train_score                                                               0.003135
#
# rank_test_score                                                                     10  \
# mean_fit_time                                                                 0.566812
# std_fit_time                                                                  0.123386
# mean_score_time                                                               0.088088
# std_score_time                                                                0.052684
# param_countvectorizer__max_features                                               1000
# param_logisticregression__C                                                   0.316228
# params                               {'countvectorizer__max_features': 1000, 'logis...
# split0_test_score                                                             0.884083
# split1_test_score                                                             0.886678
# split2_test_score                                                              0.88639
# split3_test_score                                                             0.883218
# split4_test_score                                                             0.883218
# mean_test_score                                                               0.884717
# std_test_score                                                                0.001519
# split0_train_score                                                            0.906935
# split1_train_score                                                            0.904772
# split2_train_score                                                            0.904844
# split3_train_score                                                            0.907079
# split4_train_score                                                             0.90816
# mean_train_score                                                              0.906358
# std_train_score                                                               0.001335
#
# rank_test_score                      ...  \
# mean_fit_time                        ...
# std_fit_time                         ...
# mean_score_time                      ...
# std_score_time                       ...
# param_countvectorizer__max_features  ...
# param_logisticregression__C          ...
# params                               ...
# split0_test_score                    ...
# split1_test_score                    ...
# split2_test_score                    ...
# split3_test_score                    ...
# split4_test_score                    ...
# mean_test_score                      ...
# std_test_score                       ...
# split0_train_score                   ...
# split1_train_score                   ...
# split2_train_score                   ...
# split3_train_score                   ...
# split4_train_score                   ...
# mean_train_score                     ...
# std_train_score                      ...
#
# rank_test_score                                                                     26  \
# mean_fit_time                                                                 0.457093
# std_fit_time                                                                  0.171763
# mean_score_time                                                               0.078016
# std_score_time                                                                0.043832
# param_countvectorizer__max_features                                                100
# param_logisticregression__C                                                        0.1
# params                               {'countvectorizer__max_features': 100, 'logist...
# split0_test_score                                                              0.83045
# split1_test_score                                                             0.845444
# split2_test_score                                                             0.839677
# split3_test_score                                                             0.832757
# split4_test_score                                                             0.845444
# mean_test_score                                                               0.838754
# std_test_score                                                                 0.00625
# split0_train_score                                                             0.84047
# split1_train_score                                                            0.839893
# split2_train_score                                                            0.842849
# split3_train_score                                                              0.8422
# split4_train_score                                                            0.839245
# mean_train_score                                                              0.840931
# std_train_score                                                               0.001373
#
# rank_test_score                                                                     27  \
# mean_fit_time                                                                 0.505498
# std_fit_time                                                                  0.175617
# mean_score_time                                                               0.092495
# std_score_time                                                                 0.04643
# param_countvectorizer__max_features                                                100
# param_logisticregression__C                                                  31.622777
# params                               {'countvectorizer__max_features': 100, 'logist...
# split0_test_score                                                             0.828431
# split1_test_score                                                             0.845444
# split2_test_score                                                             0.837947
# split3_test_score                                                             0.834487
# split4_test_score                                                             0.847174
# mean_test_score                                                               0.838697
# std_test_score                                                                0.006943
# split0_train_score                                                            0.844291
# split1_train_score                                                            0.843209
# split2_train_score                                                            0.844363
# split3_train_score                                                             0.84393
# split4_train_score                                                            0.841768
# mean_train_score                                                              0.843512
# std_train_score                                                               0.000963
#
# rank_test_score                                                                     28  \
# mean_fit_time                                                                 0.570187
# std_fit_time                                                                  0.201776
# mean_score_time                                                               0.139153
# std_score_time                                                                0.057501
# param_countvectorizer__max_features                                                100
# param_logisticregression__C                                                   0.031623
# params                               {'countvectorizer__max_features': 100, 'logist...
# split0_test_score                                                             0.822376
# split1_test_score                                                             0.826413
# split2_test_score                                                             0.834487
# split3_test_score                                                             0.814591
# split4_test_score                                                             0.833622
# mean_test_score                                                               0.826298
# std_test_score                                                                0.007391
# split0_train_score                                                            0.828359
# split1_train_score                                                             0.82699
# split2_train_score                                                            0.836073
# split3_train_score                                                            0.831819
# split4_train_score                                                            0.826918
# mean_train_score                                                              0.830032
# std_train_score                                                               0.003505
#
# rank_test_score                                                                     29  \
# mean_fit_time                                                                  0.45899
# std_fit_time                                                                   0.14541
# mean_score_time                                                                0.10705
# std_score_time                                                                0.035602
# param_countvectorizer__max_features                                                 10
# param_logisticregression__C                                                  31.622777
# params                               {'countvectorizer__max_features': 10, 'logisti...
# split0_test_score                                                             0.768166
# split1_test_score                                                             0.785179
# split2_test_score                                                             0.769031
# split3_test_score                                                             0.768454
# split4_test_score                                                              0.77278
# mean_test_score                                                               0.772722
# std_test_score                                                                0.006446
# split0_train_score                                                            0.775591
# split1_train_score                                                            0.771626
# split2_train_score                                                            0.772852
# split3_train_score                                                            0.770689
# split4_train_score                                                            0.772059
# mean_train_score                                                              0.772563
# std_train_score                                                               0.001667
#
# rank_test_score                                                                     30  \
# mean_fit_time                                                                   0.4434
# std_fit_time                                                                   0.11704
# mean_score_time                                                               0.089485
# std_score_time                                                                0.039748
# param_countvectorizer__max_features                                                 10
# param_logisticregression__C                                                   3.162278
# params                               {'countvectorizer__max_features': 10, 'logisti...
# split0_test_score                                                             0.768166
# split1_test_score                                                             0.785179
# split2_test_score                                                             0.768743
# split3_test_score                                                             0.768454
# split4_test_score                                                              0.77278
# mean_test_score                                                               0.772664
# std_test_score                                                                 0.00648
# split0_train_score                                                            0.775591
# split1_train_score                                                            0.771626
# split2_train_score                                                             0.77278
# split3_train_score                                                            0.770617
# split4_train_score                                                            0.772059
# mean_train_score                                                              0.772535
# std_train_score                                                               0.001681
#
# rank_test_score                                                                     30  \
# mean_fit_time                                                                 0.484707
# std_fit_time                                                                  0.090413
# mean_score_time                                                               0.122469
# std_score_time                                                                0.084917
# param_countvectorizer__max_features                                                 10
# param_logisticregression__C                                                       10.0
# params                               {'countvectorizer__max_features': 10, 'logisti...
# split0_test_score                                                             0.768166
# split1_test_score                                                             0.785179
# split2_test_score                                                             0.768743
# split3_test_score                                                             0.768454
# split4_test_score                                                              0.77278
# mean_test_score                                                               0.772664
# std_test_score                                                                 0.00648
# split0_train_score                                                            0.775591
# split1_train_score                                                            0.771626
# split2_train_score                                                             0.77278
# split3_train_score                                                            0.770689
# split4_train_score                                                            0.772059
# mean_train_score                                                              0.772549
# std_train_score                                                               0.001665
#
# rank_test_score                                                                     32  \
# mean_fit_time                                                                 0.517979
# std_fit_time                                                                  0.097612
# mean_score_time                                                               0.092764
# std_score_time                                                                0.042472
# param_countvectorizer__max_features                                                 10
# param_logisticregression__C                                                        1.0
# params                               {'countvectorizer__max_features': 10, 'logisti...
# split0_test_score                                                             0.764129
# split1_test_score                                                              0.78489
# split2_test_score                                                             0.768743
# split3_test_score                                                             0.767589
# split4_test_score                                                             0.772203
# mean_test_score                                                               0.771511
# std_test_score                                                                 0.00717
# split0_train_score                                                            0.773933
# split1_train_score                                                             0.77141
# split2_train_score                                                             0.77278
# split3_train_score                                                            0.770473
# split4_train_score                                                            0.772059
# mean_train_score                                                              0.772131
# std_train_score                                                               0.001178
#
# rank_test_score                                                                     33  \
# mean_fit_time                                                                 0.646781
# std_fit_time                                                                  0.242588
# mean_score_time                                                               0.090614
# std_score_time                                                                0.055584
# param_countvectorizer__max_features                                                 10
# param_logisticregression__C                                                   0.316228
# params                               {'countvectorizer__max_features': 10, 'logisti...
# split0_test_score                                                             0.764129
# split1_test_score                                                             0.784602
# split2_test_score                                                             0.768743
# split3_test_score                                                             0.767589
# split4_test_score                                                             0.772203
# mean_test_score                                                               0.771453
# std_test_score                                                                0.007062
# split0_train_score                                                            0.773861
# split1_train_score                                                            0.771338
# split2_train_score                                                             0.77278
# split3_train_score                                                            0.770473
# split4_train_score                                                            0.772059
# mean_train_score                                                              0.772102
# std_train_score                                                               0.001166
#
# rank_test_score                                                                     34  \
# mean_fit_time                                                                 0.576224
# std_fit_time                                                                  0.186778
# mean_score_time                                                               0.070215
# std_score_time                                                                0.030401
# param_countvectorizer__max_features                                                 10
# param_logisticregression__C                                                        0.1
# params                               {'countvectorizer__max_features': 10, 'logisti...
# split0_test_score                                                             0.763841
# split1_test_score                                                             0.781719
# split2_test_score                                                             0.766148
# split3_test_score                                                             0.767589
# split4_test_score                                                              0.77278
# mean_test_score                                                               0.770415
# std_test_score                                                                0.006368
# split0_train_score                                                            0.773573
# split1_train_score                                                            0.769752
# split2_train_score                                                            0.771122
# split3_train_score                                                            0.770112
# split4_train_score                                                            0.772203
# mean_train_score                                                              0.771352
# std_train_score                                                                 0.0014
#
# rank_test_score                                                                     35
# mean_fit_time                                                                 0.502041
# std_fit_time                                                                   0.08517
# mean_score_time                                                               0.093874
# std_score_time                                                                0.059443
# param_countvectorizer__max_features                                                 10
# param_logisticregression__C                                                   0.031623
# params                               {'countvectorizer__max_features': 10, 'logisti...
# split0_test_score                                                             0.764706
# split1_test_score                                                             0.761822
# split2_test_score                                                             0.763841
# split3_test_score                                                             0.764129
# split4_test_score                                                             0.771915
# mean_test_score                                                               0.765283
# std_test_score                                                                0.003455
# split0_train_score                                                             0.76831
# split1_train_score                                                            0.756848
# split2_train_score                                                             0.76831
# split3_train_score                                                            0.768094
# split4_train_score                                                            0.769103
# mean_train_score                                                              0.766133
# std_train_score                                                               0.004655
#
# [21 rows x 35 columns]

# %%
best_params = grid_search.best_params_
print(best_params)
best_max_features = best_params['countvectorizer__max_features']
best_C = best_params['logisticregression__C']
best_score = grid_search.best_score_
# Out:
# {'countvectorizer__max_features': 100000, 'logisticregression__C': np.float64(1.0)}

# %%
grader.check("q3.3")
# Out:
# q3.3 results: All test cases passed!

# %% [markdown]
# <br><br>

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ### 3.4 Discussion
# rubric={points}
#
# - Do the best values of hyperparameters found by Grid Search agree with what you found in 3.1 and 3.2?
# - Generally speaking, _should_ these values agree with what you found in parts  3.1 and 3.2? Why or why not?

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_3.4
#
# </div>
#
# _Points:_ 2

# %% [markdown]
# The best values of hyperparameters agree with what I found in 3.1 and 3.2 .
# Generally speaking it would be nice if they agree with the values I found in 3.1 and 3.2. But sometimes the values chosen by gridsearch can be overfitting values since they choose params solely based on test_score thus their best params may cause overfitting. So even if the best params chosen by gridsearch don't agree wwith the values I found on 3.1 and 3.2, it is understandable.

# %% [markdown]
# <!-- END QUESTION -->
#
# <br><br>

# %% [markdown]
# ### 3.5 Test score
# rubric={autograde}
#
# **Your tasks:**
# - Evaluate your final model on the test set. Store the test accuracy in the variable called `test_score`.

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_3.5
#
# </div>
#
# _Points:_ 2

# %%
test_score = grid_search.score(X_test, y_test)
print(test_score)
...
# Out:
# 0.891780716592342
# Ellipsis

# %%
grader.check("q3.5")
# Out:
# q3.5 results: All test cases passed!

# %% [markdown]
# <br><br>

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ### 3.6 Discussion
# rubric={points}
#
# - How does your test accuracy compare to your validation accuracy?
# - If they are different: do you think this is because you "overfitted on the validation set", or simply random luck?

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_3.6
#
# </div>
#
# _Points:_ 2

# %% [markdown]
# The test score is slightly lower than the cross validation score, which means the model performs well on unseen data. The difference between two values are very small, therefore, it's unlikely to caused by overfitting.

# %% [markdown]
# <!-- END QUESTION -->
#
# <br><br><br><br>

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ## Exercise 4: Very short answer questions
# <hr>
# rubric={points}
#
# Each question is worth 2 points. Max 2 sentences per answer.

# %% [markdown]
# 1. What is the problem with calling `fit_transform` on your test data with `CountVectorizer`?
# 2. If you could only access one of `predict` or `predict_proba`, which one would you choose? Briefly explain.
# 3. What are two advantages of `RandomizedSearchCV` over `GridSearchCV`?

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_4
#
# </div>
#
# _Points:_ 6

# %% [markdown]
# 1. If you call fit_transform on your test data, it will create bag of workds based on the test data during fit() with makes the model learn from the test data, which violate golden rules
# 2. I would choose predict_proba() because it provides probability scores, allowing for greater flexibility in setting decision thresholds and understanding model confidence.
# 3. Two advantages: 1. RandomizedSearchCV can be limited the number of iterations it runs so it does not exhaust the machine resources if controlled well while GridSearchCV can exhaust the machine 2.Adding not meaningful parameteres do not affect the performance of RandomizedSearchCV since it runs with fixed number of iterations

# %% [markdown]
# <!-- END QUESTION -->
#
# <br><br><br><br>

# %% [markdown]
# **Before submitting your assignment, please make sure you have followed all the instructions in the Submission instructions section at the top.**

# %% [markdown]
# Congratulations on finishing the homework!
#
# ![](./img/eva-well-done.png)
